# %% [markdown]
# # Sequence Analysis Example
# This notebook shows how to read a sample FASTA file and view basic statistics.

# %%
def dummy():
    print("This is a placeholder for your sequence analysis")

dummy()
